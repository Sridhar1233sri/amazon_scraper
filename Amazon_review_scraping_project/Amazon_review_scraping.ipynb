# %%
pip install apify-client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.3 MB/s eta 0:00:00
# ...

# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your Apify API token
# Replace '<YOUR_API_TOKEN>' with your token.
client = ApifyClient("<YOUR_API_TOKEN>")

# Prepare the Actor input
run_input = {
    "productUrls": [{ "url": "https://www.amazon.in/iQOO-Tornado-Storage-Snapdragon-FlashCharge/dp/B07WHQHNZC/ref=sr_1_1_sspa?dib=eyJ2IjoiMSJ9.GnltgpOARH1jXrIWO9crSpfqN7SOSnmxn8bukE3ZXfc0PVzp1kWTKXKpJocsz7-eBesNM3j2pi8upxcS4Ad8gXOs01Kbx18X3bAio51-1FHxBqZaLvHVJsExRWmi2hUBM99MJgNhaD49nv6BHXZ0rwhyiT4cErjoK3pLLZGLAmApxFy7uj322PSaFvz7yE42OS7QhKF9F0WXEoumK5pTROtlKC1UC_c1qF3Icko2xoA.TA4VAkQzvDBzew4J1SaD7Qo8GREt3vsyoBFX_dxxMYc&dib_tag=se&keywords=iqoo&qid=1729398826&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1" }],
    "maxReviews": 250,
    "filterByRatings": ["allStars"],
    "proxyCountry": "AUTO_SELECT_PROXY_COUNTRY",
}

# Run the Actor and wait for it to finish
run = client.actor("junglee/amazon-reviews-scraper").call(run_input=run_input)

# Fetch and print Actor results from the run's dataset (if there are any)
print("💾 Check your data here: https://console.apify.com/storage/datasets/" + run["defaultDatasetId"])
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    print(item)

# 📚 Want to learn more 📖? Go to → https://docs.apify.com/api/client/python/docs/quick-start
# Out:
# 💾 Check your data here: https://console.apify.com/storage/datasets/Tq0QHCbgctTNNulfX
# ...
